# %%
from pypokerengine.api.game import setup_config, start_poker
from randomplayer import RandomPlayer
from raise_player import RaisedPlayer
from rate_player import RatePlayer
from all_raise_player import AllRaisePlayer

#TODO:config the config as our wish
config = setup_config(max_round=100, initial_stack=10000, small_blind_amount=10)

# config.register_player(name="call_player", algorithm=CallPlayer())
# config.register_player(name="random", algorithm=RandomPlayer())
config.register_player(name="runable", algorithm=RaisedPlayer())
config.register_player(name="allraise", algorithm=AllRaisePlayer())

# %%
game_result = start_poker(config, verbose=1)
print game_result
# Out:
# Started the round 1
# Street "preflop" started. (community card = [])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['CK', 'H6', 'SK'])
# "allraise" declared "raise:20"
# "runable" declared "call:20"
# Street "turn" started. (community card = ['CK', 'H6', 'SK', 'DK'])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "river" started. (community card = ['CK', 'H6', 'SK', 'DK', 'SA'])
# "allraise" declared "raise:40"
# "runable" declared "fold:0"
# "['allraise']" won the round 1 (stack = {'runable': 9900, 'allraise': 10100})
# Started the round 2
# Street "preflop" started. (community card = [])
# "runable" declared "call:20"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['D4', 'ST', 'C7'])
# "runable" declared "fold:0"
# "['allraise']" won the round 2 (stack = {'runable': 9860, 'allraise': 10140})
# Started the round 3
# Street "preflop" started. (community card = [])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['D7', 'C8', 'D9'])
# "allraise" declared "raise:20"
# "runable" declared "call:20"
# Street "turn" started. (community card = ['D7', 'C8', 'D9', 'S6'])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "river" started. (community card = ['D7', 'C8', 'D9', 'S6', 'D6'])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# "['runable']" won the round 3 (stack = {'runable': 10000, 'allraise': 10000})
# Started the round 4
# Street "preflop" started. (community card = [])
# "runable" declared "call:20"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['S2', 'HJ', 'SQ'])
# "runable" declared "call:0"
# "allraise" declared "raise:20"
# "runable" declared "call:20"
# Street "turn" started. (community card = ['S2', 'HJ', 'SQ', 'HA'])
# "runable" declared "call:0"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "river" started. (community card = ['S2', 'HJ', 'SQ', 'HA', 'D2'])
# "runable" declared "call:0"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# "['runable']" won the round 4 (stack = {'runable': 10140, 'allraise': 9860})
# Started the round 5
# Street "preflop" started. (community card = [])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['C4', 'C9', 'HA'])
# "allraise" declared "raise:20"
# "runable" declared "call:20"
# Street "turn" started. (community card = ['C4', 'C9', 'HA', 'HK'])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "river" started. (community card = ['C4', 'C9', 'HA', 'HK', 'D8'])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# "['allraise']" won the round 5 (stack = {'runable': 10000, 'allraise': 10000})
# Started the round 6
# Street "preflop" started. (community card = [])
# "runable" declared "call:20"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['C2', 'H4', 'C5'])
# "runable" declared "call:0"
# "allraise" declared "raise:20"
# "runable" declared "call:20"
# Street "turn" started. (community card = ['C2', 'H4', 'C5', 'DQ'])
# "runable" declared "call:0"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "river" started. (community card = ['C2', 'H4', 'C5', 'DQ', 'HK'])
# "runable" declared "fold:0"
# "['allraise']" won the round 6 (stack = {'runable': 9900, 'allraise': 10100})
# Started the round 7
# Street "preflop" started. (community card = [])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['HA', 'HQ', 'CJ'])
# "allraise" declared "raise:20"
# "runable" declared "fold:0"
# "['allraise']" won the round 7 (stack = {'runable': 9860, 'allraise': 10140})
# Started the round 8
# Street "preflop" started. (community card = [])
# "runable" declared "call:20"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['C6', 'C5', 'CJ'])
# "runable" declared "fold:0"
# "['allraise']" won the round 8 (stack = {'runable': 9820, 'allraise': 10180})
# Started the round 9
# Street "preflop" started. (community card = [])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['HJ', 'DQ', 'S7'])
# "allraise" declared "raise:20"
# "runable" declared "call:20"
# Street "turn" started. (community card = ['HJ', 'DQ', 'S7', 'DJ'])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "river" started. (community card = ['HJ', 'DQ', 'S7', 'DJ', 'D3'])
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# "['allraise']" won the round 9 (stack = {'runable': 9680, 'allraise': 10320})
# Started the round 10
# Street "preflop" started. (community card = [])
# "runable" declared "call:20"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "flop" started. (community card = ['D7', 'HQ', 'D3'])
# "runable" declared "call:0"
# "allraise" declared "raise:20"
# "runable" declared "call:20"
# Street "turn" started. (community card = ['D7', 'HQ', 'D3', 'D9'])
# "runable" declared "call:0"
# "allraise" declared "raise:40"
# "runable" declared "call:40"
# Street "river" started. (community card = ['D7', 'HQ', 'D3', 'D9', 'HJ'])
# "runable" declared "fold:0"
# "['allraise']" won the round 10 (stack = {'runable': 9580, 'allraise': 10420})
# {'players': [{'stack': 9580, 'state': 'participating', 'name': 'runable', 'uuid': 'aiyhrlkfnpiqzngjkfypcq'}, {'stack': 10420, 'state': 'participating', 'name': 'allraise', 'uuid': 'exppwifqtjgbcpqmaiqmim'}], 'rule': {'ante': 0, 'blind_structure': {}, 'max_round': 10, 'initial_stack': 10000, 'small_blind_amount': 10}}
